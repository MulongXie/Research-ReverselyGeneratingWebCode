# %%
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.headless = True
driver = webdriver.Chrome(executable_path='D:\\webdriver\\chromedriver.exe', options=options)

# %%
driver.get("https://stackoverflow.com/questions/25356440/need-to-dump-entire-dom-tree-with-element-id-from-selenium-server")

# %%
tree = driver.find_elements_by_xpath("//*")

# %%
tree
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0389e37855e226a4eac9a0490ef0ff54", element="0.39150606150314626-7")>,
# ...

# %%
str_tree = driver.execute_script("return document.documentElement.outerHTML")

# %%
str_tree
# Out:
# '<html class="html__responsive"><head>\n\n        <title>python - Need to dump entire DOM tree with element id from selenium server - Stack Overflow</title>\n        <link rel="shortcut icon" href="https://cdn.sstatic.net/Sites/stackoverflow/img/favicon.ico?v=4f32ecc8f43d">\n        <link rel="apple-touch-icon image_src" href="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon.png?v=c78bd457575a">\n        <link rel="search" type="application/opensearchdescription+xml" title="Stack Overflow" href="/opensearch.xml">\n        <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0">\n\n\n        <meta property="og:type" content="website">\n        <meta property="og:url" content="https://stackoverflow.com/questions/25356440/need-to-dump-entire-dom-tree-with-element-id-from-selenium-server">\n        <meta property="og:site_name" content="Stack Overflow">\n        <meta property="og:image" itemprop="image primaryImageOf
# ...

# %%
f=open('dom.txt', 'w',  encoding="utf-8")

# %%
f.write(str_tree)
# Out:
# 219341
