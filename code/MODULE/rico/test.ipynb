# %%
import pandas as pd

# %%
label = pd.read_csv('merged.csv', index_col=0)

# %%
label
# Out:
#                               App Package Name           Category  UI Number
# 0                        com.guideme.movieboxa  Books & Reference      17184
# 1                        com.guideme.movieboxa  Books & Reference      17185
# 2                        com.guideme.movieboxa  Books & Reference      17186
# 3                        com.guideme.movieboxa  Books & Reference      17187
# 4                        com.guideme.movieboxa  Books & Reference      17188
# 5                         com.aon.mangaareader             Comics      14596
# 6                         com.aon.mangaareader             Comics      14597
# 7                         com.aon.mangaareader             Comics      14598
# 8                              com.diaohs.cola   Health & Fitness      16103
# 9                              com.diaohs.cola   Health & Fitness      16104
# 10                             com.diaohs.cola   Health & Fitness      16105
# ...

# %%
label = label.sort_values('App Package Name')

# %%
label.to_csv('merged.csv')

# %%
# Out:
# Index(['App Package Name', 'Category', 'UI Number'], dtype='object')
